# %% [markdown]
# # Introduction
#
# Game Master △  ▢  ◯ :
#
# Welcome Player 259.
#
# Even though you hold a business degree, poor financial decisions have had a clear impact.
#
# Now, you are in debt, on the edge of financial ruin.
#
#
#
# We found you at a casino in Las Vegas, and gave you our business card, for a way to win quick money.
#
# You took it, called us and we kindly picked you up and brought you here.
#
# Even though it is too late for you now, here is some information about our game:
#
# <a href="https://www.youtube.com/watch?v=l1NsPNWmzP8">Click this link to understand the game.</a>
#
#
# In order to succeed and win the price fund, you need to survive each of the three physically challenging games.
#
# In the end, you will also need to answer a question to win the price fund.
#
# If you do not pass each of the three games and final question, you will be...
#
#
# ...eliminated.
#
#
# # Creator Notes:
#
# Thank you, player 259 for choosing to play this game. Here is some guidance:
#
# The difficulty level is high.
#
# Each game will ask you to input specific things;
#
# Such as letters, numbers, or words (such as shapes, names, direction, etc.).
#
# If you do this incorrectly, you may be eliminated. Be aware.
#
# There are fast ways to succeed in this game, but these are hard to find.
#
# Many choices lead to different paths or bring you back to a path you could have been on if you would have chosen differently before. Be aware.
#
# If you choose one wrong answer, you will automatically be eliminated and redirected to the start of the game.
# The only time you get to do a do-over is in the 'first' physical game. That is it.
#
# And with that, let the game begin.
#
#
# # Squid Game Themed Text Adventure Game: Python Edition
#
# Written by: Alyssa Brunen
#
#                           ~ Please run the code cell below. ~

# %%
#working room setup 

import time
import random

#introduction room, not a game stage  
def introduction():
    print("""
Game Master △  ▢  ◯ :
Welcome to Squid Games Player 259. 

You must survive each game in order to win the experiment. 
If you loose in one game, you are eliminated from all following games and have to restart the game. 

Each decision you make, will determine your fate in this game.
Therefore, be careful.

Good luck Player 259.


All players please follow the staff to the game hall. 
""")
    
    redlight_greenlight() # This moves us into the second room aka the first game 


# defining the first stage of the game 
def redlight_greenlight():
    print("""
You: 
What is this room? I see this figure in the front, like a girl, but it looks more like...
Like a doll?
And all of the staff are in these weird red overralls with masks on... 
The masks show either  △ , ▢ , or ◯ . 
 """) 
    time.sleep(3)# addings suspense
    print("""
Game Master △  ▢  ◯ :
Attention, all players. After you enter the game hall please stand 
Behind the white line drawn on the field and await further instructions. 

Please await further instructions.\n""")
     #building suspense for what the first game is 
    time.sleep(4)
    
    #Introduction to the first game 
    print("""    


██████╗ ███████╗██████╗     ██╗     ██╗ ██████╗ ██╗  ██╗████████╗                       
██╔══██╗██╔════╝██╔══██╗    ██║     ██║██╔════╝ ██║  ██║╚══██╔══╝                       
██████╔╝█████╗  ██║  ██║    ██║     ██║██║  ███╗███████║   ██║                          
██╔══██╗██╔══╝  ██║  ██║    ██║     ██║██║   ██║██╔══██║   ██║                          
██║  ██║███████╗██████╔╝    ███████╗██║╚██████╔╝██║  ██║   ██║▄█╗                       
╚═╝  ╚═╝╚══════╝╚═════╝     ╚══════╝╚═╝ ╚═════╝ ╚═╝  ╚═╝   ╚═╝╚═╝                       
                                                                                        
 ██████╗ ██████╗ ███████╗███████╗███╗   ██╗    ██╗     ██╗ ██████╗ ██╗  ██╗████████╗    
██╔════╝ ██╔══██╗██╔════╝██╔════╝████╗  ██║    ██║     ██║██╔════╝ ██║  ██║╚══██╔══╝    
██║  ███╗██████╔╝█████╗  █████╗  ██╔██╗ ██║    ██║     ██║██║  ███╗███████║   ██║       
██║   ██║██╔══██╗██╔══╝  ██╔══╝  ██║╚██╗██║    ██║     ██║██║   ██║██╔══██║   ██║       
╚██████╔╝██║  ██║███████╗███████╗██║ ╚████║    ███████╗██║╚██████╔╝██║  ██║   ██║       
 ╚═════╝ ╚═╝  ╚═╝╚══════╝╚══════╝╚═╝  ╚═══╝    ╚══════╝╚═╝ ╚═════╝ ╚═╝  ╚═╝   ╚═╝       
                                                                                        

Game Master △  ▢  ◯ :
Welcome to the first game. You will be playing red light, green light. 

You are allowed to move forward when \U0001f467\U0001f3fb shouts \U0001f7e2 “Green Light". 
Stop when \U0001f467\U0001f3fb shouts \U0001f534 “Red Light”.

If your movement is detected afterward, you will be eliminated. 
Those players who cross the finish line without being eliminated will pass this round. 
With that, let the first game begin.  \n""")
    #building suspense, let the user think about what could happen next 
    time.sleep(6)   
    
    #first choice in the game red light green light 
    rl_gl_first_choice = input(prompt= """
You: 
Where should I stand? 

A : Move to the front, right behind the line 
B : Move to the back, behind all other players 
C : Blend in with the other players towards the middle

~~~Please ONLY input the LETTER of the chosen path below.~~~
>  """)

    #if the user input to move to the front of the line 
    if rl_gl_first_choice == "A" or rl_gl_first_choice =="a":
        print("""
You: 
Ok, I  moved to the front... But was that the right decicison?""")
        time.sleep(1)
        #begin to make it more dramatic when reading, suspense building 
        print("""
        
\U0001f467\U0001f3fb:
'GREEN LIGHT'

You: 

Thank god noone is in front of me. 

\U0001f467\U0001f3fb:
"RED LIGHT"
        """)
        time.sleep(2)
        #nested statements to see what user does next after his first conditional statement 
        rl_gl_second1_choice = input( prompt= """

You: 
The doll said, 'green light' again and the music is beginning to play...
Should I run?

A : YES! RUN!
B : Play it safe, run a little bit, but stop early! 
C : No, I will just stay where I am now. 

~~~Please input the letter of the chosen path below.~~~
>""")
        #user did not want to be a safe player and book it to the end 
        if rl_gl_second1_choice == "A" or rl_gl_second1_choice == "a":
            print("""
You: 
I am so fast! I can see the finish line! I am so close! 

\U0001f467\U0001f3fb: 
"RED LIGHT"

You: 
Did I stop too late? """)
            time.sleep(2)
            print("""
\U0001f4a5            
            """)
            time.sleep(2)
            #booking it unfortunatly lead to failing the game 
            fail()
        
        elif rl_gl_second1_choice == "B" or rl_gl_second1_choice == "b":
            print("""
You: 
Ok I made like 20 steps forward, but very cautiously. 
I have a feeling she will turn around soon again.  
""")
            time.sleep(2)
            rl_gl_third1_choice = input(prompt= """
You:
What should I do next? 

A : Stop. 
B : Maybe make 3 more steps, it will get me to the end quicker.
C : We have to run, at least a little bit! The time is running out!

~~~Please input the letter of the chosen path below.~~~
>""")
            if rl_gl_third1_choice == "A" or rl_gl_third1_choice== "a": #more input options 
                print("""
You: 
OK I stopped. That was probably the best decision.

\U0001f467\U0001f3fb: 
"RED LIGHT"

\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5

You:
I am still alive. Thank goodness I stopped early. 
The finish line is pretty close. When she turns around next I think I can make it. 
""")
                time.sleep(3) #adding suspense 
                rl_gl_sprint = print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

You: 
I need a sprint boost!!! 
""")
    
                presses = 3
    # while loop for the sprint 
                while presses > 0: 
                    input("""
~~~Please utilize the enter key in order go give sprint boost.~~~
>""")
                    presses -= 1 #takes a press away from 3 
    
                print("""
You:
I MADE IT!!! 
But what could the next game be?""")
                dalgona() #leading to next game stage 

            # more nested conditional statements     
            elif rl_gl_third1_choice == "B" or rl_gl_third1_choice ==  "b":
                print("""
You: 
I am slowly making few more steps... Wow I can see the finish line! 
I am so close!
Let me make one more...

\U0001f467\U0001f3fb: 
"RED LIGHT" 

You: 
Did I stop too late? """)
                time.sleep(1) # adding suspense
                print("""
\U0001f4a5            

I was not shot. Thank god. 

\U0001f467\U0001f3fb: 
"GREEN LIGHT"

You: 
I am almost at the line!! 

I CROSSED THE FINISH LINE! I AM SAFE FROM THIS GAME 
""")
                dalgona() #going to next room 
           
            
            elif rl_gl_third1_choice == "C" or rl_gl_third1_choice == "c": #more user input statements 
                print("""
You: 
I can see the finish line, I am so close!!!
I can make it!

\U0001f467\U0001f3fb: 
"RED LIGHT"

You: 
Did I stop too late? """)
                time.sleep(2)
                print("""
\U0001f4a5            
            """)
                time.sleep(2)
            #booking it unfortunatly lead to failing the game 
                fail()
            else: #else statements 
                time.sleep(3) #adding suspense 
                print("""
You:
I did not decide on what to do... I guess I will stay here and see what happens...
            """)
                time.sleep(3) #adding suspense 
                print("""
\U0001f467\U0001f3fb: 
"GREEN LIGHT"

You: 
I think I will stay where I am. But I should make at least one step forward...
            """)
                time. sleep(3) #adding suspense 
                print("""
\U0001f467\U0001f3fb: 
"Red LIGHT"
\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5            
           
Game Master △  ▢  ◯ :
Player 259,... 
            """)
                time. sleep(3) #adding suspense 
                print("""
Game Master △  ▢  ◯ :
...eliminated. 
            """)
                time.sleep(3)
                fail() #this will lead to the fail function
            
        if rl_gl_second1_choice == "C" or rl_gl_second1_choice ==  "c": #more input from user 
            time.sleep(3)
            print("""
\U0001f467\U0001f3fb: 
"GREEN LIGHT"

You: 
Nope I am staying where I am. 
But I should make at least one step forward...
            """)
            time. sleep(3) #adding suspense 
            print("""
\U0001f467\U0001f3fb: 
"Red LIGHT"
\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5            
            """)
            time.sleep(3)
            print("""
Game Master △  ▢  ◯ :
Player 259,... 
            """)
            time. sleep(3)
            print("""
Game Master △  ▢  ◯ :
...eliminated. 
            """)
            time.sleep(3) #adding suspense 
            fail()
            
        else: #else statements for the function above 
            time.sleep(3)
            print("""
You:
I did not decide on what to do... 
I guess I will stay here and see what happens...
            """)
            time.sleep(3) #adding suspense 
            print("""
\U0001f467\U0001f3fb: 
"GREEN LIGHT"

You: 
I think I will stay where I am. But I should make at least one step forward...
            """)
            time. sleep(3)
            print("""
\U0001f467\U0001f3fb: 
"Red LIGHT"
\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5            
            """)
            time.sleep(3)
            print("""
Game Master △  ▢  ◯ :
Player 259,... 
            """)
            time. sleep(3) #adding more suspense 
            print("""
Game Master △  ▢  ◯ :
...eliminated. 
            """)
            time.sleep(3)
            fail() #too bad, the useer has failed again
                
    elif rl_gl_first_choice == "B" or rl_gl_first_choice=="b": #the first choice if for user going to the back 
        print(""""
You: 
Ok I went to the back... 
But what if someone in front of me has an issue?""")
        time.sleep(2) # adding suspense again
        print("""
\U0001f467\U0001f3fb: 
"GREEN LIGHT"

You: 
Everyone is so slow, now is the perfect time to run! 
What is everyone waiting for? 
""")
        time.sleep(3)
        print("""
\U0001f467\U0001f3fb: 
"RED LIGHT"

You: 
Oh noooo... The person in front of me is about to fall! And the Doll is about
to turn around! I am going to fall too!""")
        # adding input on users choice of what to do next 
        rl_gl_second2_choice =input(prompt= """
You: 
What do I do?
A : Catch the person in front of me by their jacket. 
B : Let them fall, and risk falling on them too. 
C : Give them a push, hoping they will be static on the ground 
    before the doll turns, and you can also stand in a stable stance.
    
~~~Please input the letter of the chosen path below.~~~
>""")
        if rl_gl_second2_choice == "A" or rl_gl_second2_choice=="a": #if a choice (A) was taken 
            print("""
You: 
I cought them! 

\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5

\U0001f467\U0001f3fb: 
"GREEN LIGHT"

You:
I can make it till the end! 
""")
            #adding more user input on their next choice
            rl_gl_third2_choice = input(prompt= """
You:
What should I do next? 

A : Stop. 
B : Maybe make 3 more steps, it will get me to the end quicker.
C : We have to run, at least a little bit! The time is running out!

~~~Please input the letter of the chosen path below.~~~
>""") 
            if rl_gl_third2_choice == "A" or rl_gl_third2_choice== "a": #if the user input choice
                print("""
You: 
OK I stopped. That was probably the best decision.

\U0001f467\U0001f3fb: 
"RED LIGHT"

\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5

You:
The finish line is pretty close. When she turns around next I think I can make it. 
""")
                time.sleep(3) #adding suspense again
                #setting up a sprint 
                rl_gl_sprint = print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

You: 
I need a sprint boost!!! 
""")
    
                presses = 2 #user has three presses, function set up
    
                while presses > 0: #while loop for the sprint 
                    input("""
~~~Please utilize the enter key to give sprint boost.~~~
>""")
                    presses -= 1 # takes a press away 
    
                print("""
You:
I MADE IT!!! 
But what could the next game be?""")
                dalgona() #leads to the next room

                
            elif rl_gl_third2_choice == "B" or rl_gl_third2_choice=="b": # else if clause if user chose path b 
                print("""
You: 
I am slowly making few more steps...  
I am so close!
Let me make one more...

\U0001f467\U0001f3fb: 
"RED LIGHT" \n  """)
                time.sleep(2)
                print("""
You: 
Did I stop too late? """)
                time.sleep(2)
                print("""
\U0001f4a5            
            """)
                time.sleep(1) # adding suspense on survival
                print("""
You: 
I was not shot. Thank god. 

\U0001f467\U0001f3fb: 
"GREEN LIGHT"

You: 
I am almost at the line!! 
I CROSSED THE FINISH LINE! I AM SAFE FROM THIS GAME 
""")
                dalgona() #leads to next game 
           
            
            elif rl_gl_third2_choice == "C" or rl_gl_third2_choice == "c": #elseif if the user chose path c
                print("""
You: 
I can see the finish line, I am so close!!!
I can make it!

\U0001f467\U0001f3fb: 
"RED LIGHT"

You: 
Oh no. *stops mid run*
""")
                time.sleep(3)
                print("""
You: 
Did I stop too late? """)
                time.sleep(2) #suspense on survival
                print("""
\U0001f4a5            
            """)
                time.sleep(2)
            #booking it unfortunatly lead to failing the game 
                fail()
                
        elif rl_gl_second2_choice == "B" or rl_gl_second2_choice=="b": # else if, if the user chose path b 
            time.sleep(3)
            print("""
You: 
The old man fell! I have to jump over them... 
Or should I help them get back up? 
The doll will turn around soon I think...
What should I do? """)
            time.sleep(3) 
            #setting up the next input prompt 
            rl_gl_third21_choice = input(prompt= """
You: 
I think I should...

A: Help the old man of course! 
B: Jump over the man!
C: Just stand still here and wait for the red light. Just in case.

~~~Please input the letter of the chosen path below.~~~
>""")
            if rl_gl_third21_choice== "A" or rl_gl_third21_choice =="a": #if the user chose path A
                time.sleep(3)
                print("""
You: 
Ok, I will help the man. """)
                time.sleep(3)
                print("""
*As you were helping the old man*

\U0001f467\U0001f3fb: 
"RED LIGHT"               
""")
                time.sleep(3) #adding suspense 
                print("""
\U0001f4a5     \U0001f4a5
""")
                time.sleep(2)
                print("""
Gamemaster △  ▢  ◯ :
Player 356 and Player 259,... 
            """)
                time. sleep(3)
                print("""
Gamemaster △  ▢  ◯ :
...eliminated. 
            """)
                time.sleep(3)
                fail() #this leads to the fail function
            elif rl_gl_third21_choice =="B" or rl_gl_third21_choice=="b": # else if the user chose path b 
                time.sleep(3)
                print("""
*Jumping over the man and stand still* 

\U0001f467\U0001f3fb: 
"RED LIGHT" """)
                time.sleep(1)
                print("""
\U0001f467\U0001f3fb: 
"GREEN LIGHT"        

You: 
I can see the finish line! Lets keep running to the end! """)
                time.sleep(2)
                print("""
*Crosses the finish line with 14 seconds left*

You: 
I made it! And the old man did too! Thank goodness we are both alive!""")
                time.sleep(2) # adding suspense on survival 
                print("""
Gamemaster △  ▢  ◯ :
Player 259, pass. """)
                time.sleep (2)
                dalgona() #leads to the next room 
            elif rl_gl_third21_choice=="C" or rl_gl_third21_choice =="c": #else if clause if the user chose path c 
                print("""
You: 
OK I stopped. That was probably the best decision.

\U0001f467\U0001f3fb: 
"RED LIGHT"

\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5

You:
I am still alive. Thank goodness I stopped early. 
The finish line is pretty close. When she turns around next I think I can make it. 
""")
                time.sleep(3)
                #setting up the sprint function below 
                rl_gl_sprint = print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

You: 
I need a sprint boost!!! 
""")
    
                presses = 3 # the user has to do 3 presses 
    
                while presses > 0: # while loop beginning 
                    input("""
~~~Please utilize the enter key to give sprint boost.~~~
>""")
                    presses -= 1 # takes one press away from 3 
    
                print("""
You:
I MADE IT!!! 
But what could the next game be?""")
                dalgona() # leads to the next room 
            else: 
                time.sleep(3)
                print("""
You: 
That was not a decicison I was prepared for. 
I will stay where I am now and see what happens instead. 
""")
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
The time is now over. 

\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5
""")
                time.sleep(3) #adding suspense 
                print("""
Game Master △  ▢  ◯ :
Player 259,... 
            """)
                time. sleep(3)
                print("""
Game Master △  ▢  ◯ :
...eliminated. 
            """)
                time.sleep(3)
                fail()
            
    elif rl_gl_first_choice == "C" or rl_gl_first_choice== "c": #else if clause if user chose path c: blend in 
        print("""
You: 
Ok, I will blend into the crowd...  
I just need to remember that the Game Masters have constant vison on me... 
even in the crowd...\n""")
        time.sleep(2)
        print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

You: 
Ok I will run a bit! 
        """)
        time.sleep(2) # adding suspense & setting up user input below 
        rl_gl_second3_choice = input (prompt = """
\U0001f467\U0001f3fb:
"RED LIGHT"

You: 
I stopped in time. We have 4:34min left...
What should I do when the doll shouts "GREEN LIGHT"? 

A : Keep Running and make it to the end zone. 
B : Cautiously walk to the end. I have enough time.

~~~Please input the letter of the chosen path below.~~~
>""")
        if rl_gl_second3_choice == "A" or rl_gl_second3_choice =="a": # if the user chose path A 
            time.sleep(2)
            print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

You: 
Lets run!!! """)
            time.sleep(2)
            #setting up sprint function below
            rl_gl_sprint = print("""

You: 
Just a little bit further! She has not turned yet!  
.\n""")
    
            presses = 3 #the user has 3 inputs 
    
            while presses > 0: #while loop beginning 
                input("""
~~~Please utilize the enter key to give sprint boost.~~~
>'""")
                presses -= 1 #takes one press away from
    
            print("""
You:
There it is! The finish line! I made it!!  
""")
            time.sleep(2)
            print("""
Game Master △  ▢  ◯ :
Player 259, pass. """)
            time.sleep (2)
            dalgona() #leads to the next room 
        elif rl_gl_second3_choice == "B" or rl_gl_second3_choice=="b": #else if the user chose path b 
            time.sleep(1)
            print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

You: 
Ok I will walk a little further. I still have 4 minutes left. """)
            time.sleep(2)
            print("""
\U0001f467\U0001f3fb:
"RED LIGHT"


\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5""")
            time.sleep(1) #adding suspense 
            print("""
You: 
I stopped in time. I am still in this game.""")
            time. sleep(1)
            #new input set up 
            rl_gl_third31_choice = input(prompt= """
\U0001f467\U0001f3fb:
"GREEN LIGHT"

You: 
How many steps should I take? 

~~~Please input a primary number, including and between 1 and 20.~~~
>""") 
            if rl_gl_third31_choice =="1" or rl_gl_third31_choice <="13": #if the user chose numbers between 1 and 13 
                time.sleep(3)
                print("""
\U0001f467\U0001f3fb:
"RED LIGHT"

You: 
I stopped just in time. Thank god.""")
                time.sleep(2)
                print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

*You begin running*

You: 
I can make it to the finish line! """)
                time.sleep(2) #adding suspense 
                print("""
You:
There it is! The finish line! I made it!!  
""")
                time.sleep(1)
                print("""
Game Master △  ▢  ◯ :
Player 259, pass. """)
                time.sleep (2)
                dalgona() #leads to the next room 
            elif rl_gl_third31_choice >="14" or rl_gl_third31_choice <="20": #if the user input between 14 and 20 steps 
                time.sleep(1)
                print("""
\U0001f467\U0001f3fb:
"RED LIGHT"

You: 
I stopped just in time, and made a lot of progress forward.
Thank god.""")
                time.sleep(2)
                print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

*You begin running*

You: 
I can make it to the finish line! """)
                time.sleep(3) #adding suspense 
                print("""
You:
There it is! The finish line! I made it!!  
""")
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
Player 259, pass. """)
                time.sleep (2)
                dalgona() #leading to the next room
            else: #else clause if the number was not in the number range 
                time.sleep(3)
                print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

*You start running, but do not stop, as you did not correctly clarify how many steps*
""")
                time.sleep(3)
                print("""
\U0001f467\U0001f3fb: 
"RED LIGHT"               
""")
                time.sleep(3) #adding suspense 
                print("""
\U0001f4a5     \U0001f4a5
""")
                time.sleep(2)
                print("""
Game Master △  ▢  ◯ :
Player 259,... 
            """)
                time. sleep(3)
                print("""
Game Master △  ▢  ◯ :
...eliminated. 
            """)
                time.sleep(3)
                fail() # leading to the fail function 
            
        else: 
            time.sleep(3)
            print("""
\U0001f467\U0001f3fb:
"GREEN LIGHT"

You: 
Ok I will walk a little further. I still have 4 minutes left. """)
            time.sleep(3)
            print("""
\U0001f467\U0001f3fb:
"RED LIGHT"


\U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5 \U0001f4a5""")
            time.sleep(2) #adding suspense 
            print("""
Game Master △  ▢  ◯ :
Player 259,... 
            """)
            time. sleep(3)
            print("""
Game Master △  ▢  ◯ :
...eliminated. 
            """)
            time.sleep(3)
            fail() #leads to the fail function 
        
              
    else:
        print("""
Game Master △  ▢  ◯ :
Player 259, eliminated. 
You remained at the starting line due to a hesitant and invalid decicison. 
As this is the first game, we grant you one more try.
Please read the instructions carefully next time. 
\n""")
        time.sleep(2)
        redlight_greenlight # This moves us back to the beginning of this room 


############ SETTING UP GAME 2
def dalgona():
    print("""
Game Master △  ▢  ◯ :
Congratulations on surviving the first game. 
165 players have been eliminated. 
The price fund stands at $USD 1,345,000.     
We will begin the next game immediatly.
Players, please follow the staff into the game hall. 
    """)
    print("""
Game Master △  ▢  ◯ :
Players, 
Welcome to the second game. 
Before the second game begins, 
Choose one of the four available shapes you see on the wall. 

     \u2602\uFE0F      \U0001f53a      \u2B55      \u2B50     
Once you have chosen your shape, please stand in front of it. 

\n""")
     #building suspense for what the first game is and giving user time to read 
    time.sleep(7) 
    #setting up first choice for the dalgona game
    dalgona_first_choice= input(prompt= """
You: 
Which shape should I choose? 

- Circle 
- Triangle 
- Umberella
- Star     

~~~Please input the NAME of the shape you would like to go ahead with.~~~
>""")
#adding list for the different shapes 
    dalgona_shape_lst = ['Star', 'star', 'Triangle', 'triangle','Umbrella', 'umbrella']
    dalgona_shape = random.choice(dalgona_shape_lst) #choosing a random shape 
    dalgona_shape_wo_circle = ['Star', 'Triangle', 'Umbrella'] #list without the easiest shape (circle)
    dalgona_shape_no_circle= random.choice(dalgona_shape_wo_circle) #choosing a shape from the list with no circle

    
    if dalgona_first_choice == 'Circle' or dalgona_first_choice == 'circle':  #if user chose the shape circle 
        print(f"""
Game Master △  ▢  ◯ :
You were too hesitant and the Circle line has filled up. 
You shape for the upcoming game will be: {dalgona_shape_no_circle}
""")
        time.sleep(3) #adding suspense 
        print(f"""
Game Master △  ▢  ◯ :  
I will now explain the rules of the next game. 

*Doors with shapes open* 

Game Master △  ▢  ◯ :
All players, 
Please take one case each from the table at the front of your line. 
""")
        time. sleep(5)
        #adding print with f" because the randomly selected shape will appear then
        print(f"""
*You go and find a place to sit with your case*

Game Master △  ▢  ◯ :
Please take a moment to open the case and check the contents.

*You open the case and find a sugar cookie, 
 Which has a {dalgona_shape_no_circle} stamped into it. 
 There is also a needle inside the tin case. 
 That is probably what I will have to use?* 
        """)
        time.sleep(6)
        print("""
Game Master △  ▢  ◯ :
The second game is:  


██████╗  █████╗ ██╗      ██████╗  ██████╗ ███╗   ██╗ █████╗ 
██╔══██╗██╔══██╗██║     ██╔════╝ ██╔═══██╗████╗  ██║██╔══██╗
██║  ██║███████║██║     ██║  ███╗██║   ██║██╔██╗ ██║███████║
██║  ██║██╔══██║██║     ██║   ██║██║   ██║██║╚██╗██║██╔══██║
██████╔╝██║  ██║███████╗╚██████╔╝╚██████╔╝██║ ╚████║██║  ██║
╚═════╝ ╚═╝  ╚═╝╚══════╝ ╚═════╝  ╚═════╝ ╚═╝  ╚═══╝╚═╝  ╚═╝
                                                    
The shape you have chosen, is the shape you have to remove from the sugar cookie. 

You will pass if you trim out the shape without it breaking or cracking within 
The time limit of 5 minutes. 

If the shape in the sugar cookie breaks or cracks, you will be eliminated.  

With that, let the game begin. """)
        time.sleep(8) #adding suspense 
        print("""
You: 
Ok this is not the shape that I wanted. But I have to work with it now. 
Let me try to carve it out. 
""")
        time.sleep(3)
        #setting up user input 
        dalgona_second1_choice= input(prompt= """
You: 
This is taking way too long, and it is a lot more brittle than I expected. 

What should I try to do? 

A : I will look around to see what other people are doing
B : Let me try to lick the sugar cookie. 
    Maybe it will liquify it so I can carve it better. 
    
~~~Please input the letter of the chosen path below.~~~     
>""")
        if dalgona_second1_choice == "A" or dalgona_second1_choice == "a": #if user chose path A 
            time.sleep(1)
            print("""
You: 
Hmmmm. 
To my left is this old man next to me, he is licking the sugar cookie.

To my right is a woman. What is she holding? Is that a lighter she is using?
Wow she is almost done! The game barely even started yet! 
""")
            time.sleep(4)
            # setting up next user input
            dalgona_second12_choice = input (prompt="""
You: 
The woman is done! She passed! 
The Game Masters did not notice her using her ligter!


What should I do? 

A : Lick the sugar cookie like the old man
B : Ask the woman to give me her lighter

~~~Please input the letter of the chosen path below.~~~
>""")
            if dalgona_second12_choice =="A" or dalgona_second12_choice =="a": #if user chose path A 
                time.sleep(3)
                #setting up a funny sprint, this time for licking a cookie lol
                dalgona_lick_sprint = print("""
You: 
Ok this is definetly working...
I think I need to use more saliva on this...
\n""")
    
                presses = 1 #user does it only one time 
    
                while presses > 0: #if presses are above 0 
                    input("""
~~~Please utilize the enter key to add more saliva to the sugar cookie.~~~ 
>""")
                    presses -= 1 #takes away from the press function 
                print("""
You:
I can carve it out now! There it is!  
""")
                time.sleep(3) #adding suspense 
                print("""
Game Master △  ▢  ◯ :
Player 259, pass. """)
                time.sleep(5)
                glasstiles() #leads to the next game 
            elif dalgona_second12_choice =="B" or dalgona_second12_choice=="a": #if the user chose path b 
                time.sleep(3)
                print("""
*You turn to the woman and whisper*

You: 
Hey! Please give me your lighter!

Woman: 
Ok fine... Here you go! Do not get caught! 
""")
                time.sleep(3)
                print("""
Player 259... 
""")
                time.sleep(2) #adding suspense 
                print("""
            
\U0001f4a5            
            
...has been eliminated. 
All remaining players, 
You will be eliminated if caught passing this challenge using outside objects.
You will also be eliminated if caught aiding other players. 
            """)
                fail() #leads to the fail function
            else: #else function outcome below...
                print("""
You: 
I do not know what to do. I will wait it out. """)
                time.sleep(3)
                print("""
Player 259... 
""")
                time.sleep(2)
                print("""
            
\U0001f4a5            
            
...has been eliminated.""")
                fail() #oh well, this leads to fail 
        elif dalgona_second1_choice =="B" or dalgona_second1_choice == "b": #if user chose path b 
            time.sleep(3)
            #settinhg up the second licking sprint function lol 
            dalgona_lick_sprint = print("""
You: 
Ok this is definetly working...
I think I need to use more saliva on this...
""")
    
            presses = 1 #user has 1 press to do 
    
            while presses > 0: #while looop begin 
                input("""
~~~Please utilize the enter key to add more saliva to the sugar cookie.~~~ 
>""")
                presses -= 1 #takes away from the presses 
            print("""
You:
I can carve it out now! There it is!  
""")
            time.sleep(2)
            print("""
Game Master △  ▢  ◯ :
Player 259, pass. """)
            time.sleep(2)
            glasstiles() #leads to the next game 
        else:
            time.sleep(3)
            print("""
You: 
I did not make any decicion....I will just try carving...                
                """)
            time.sleep(5)
            print("""
*Crack noise appears*                

You: 
Oh no...""")
            time.sleep(3) #adding suspense 
            print("""
Game Master △  ▢  ◯ :
Player 259,...""")
            time.sleep(3)
            print("""
Game Master △  ▢  ◯ :
... eliminated. """)
            fail() #too bad, this also leads to fail 
                
    
    
    elif dalgona_first_choice in dalgona_shape_lst: #else if the shape was other than the circle 
        time.sleep(4)
        #adding print with f so that the shape from users stays 
        print(f"""
Game Master △  ▢  ◯ :  
The time to select your shape has ended. 
I will now explain the rules of the next game. 

*Doors that the shapes are mounted to open* 

Game Master △  ▢  ◯ :
All players, 
Please take one case each from the table at the front of your line. 

*You go to the front of the {dalgona_first_choice} line and receive a case*  
        """)
        time. sleep(8)
        print(f"""
*You go and find a place to sit with your case*

Game Master △  ▢  ◯ :
Please take a moment to open the case and check the contents.

*You open the case and find a sugar cookie,
 Which has a {dalgona_first_choice} stamped into it. 
 There is also a needle inside the tin case
 That is probably what I will have to use?* 
        """)
        time.sleep(8) #adding suspense 
        print("""
Game Master △  ▢  ◯ :
The second game is:  


██████╗  █████╗ ██╗      ██████╗  ██████╗ ███╗   ██╗ █████╗ 
██╔══██╗██╔══██╗██║     ██╔════╝ ██╔═══██╗████╗  ██║██╔══██╗
██║  ██║███████║██║     ██║  ███╗██║   ██║██╔██╗ ██║███████║
██║  ██║██╔══██║██║     ██║   ██║██║   ██║██║╚██╗██║██╔══██║
██████╔╝██║  ██║███████╗╚██████╔╝╚██████╔╝██║ ╚████║██║  ██║
╚═════╝ ╚═╝  ╚═╝╚══════╝ ╚═════╝  ╚═════╝ ╚═╝  ╚═══╝╚═╝  ╚═╝
                                                    
The shape you have chosen, is the shape you have to remove from the sugar cookie. 

You will pass,
if you trim out the shape without it breaking or cracking within the time limit of 
5 minutes. 

If the shape in the sugar cookie breaks or cracks, you will be eliminated.  

With that, let the game begin. """)
        time.sleep(8)  # adding suspense 
        #adding new input prompt below 
        dalgona_second2_choice = input(prompt="""
You: 
Oh no... well.. let me think... what should I do? 

A : start to carve it out with the needle
B : look around for clues on what to do from others 

~~~Please input the letter of the chosen path below.~~~
>""")
        
        if dalgona_second2_choice == "A" or dalgona_second2_choice == "a": #if user chose to go down path A 
            time.sleep(2)
            print(f"""
You:
Ok this sugar cookie is a lot more brittle than I thought. 
The {dalgona_first_choice} almost broke. 
I cannot keep doing this. """)
            time.sleep(4) #adding suspense 
            print("""
You: 
What else should I try? 
            """)
            time.sleep(2)
            #adding anpther input below 
            dalgona_third21_choice = input (prompt= """
You:
I think I should try...

A : Licking the sugar cookie. 
    The moisture will help liquify the sugar and makes it easier to carve
B : Spitting in the tin can and laying down the sugar cookie.

~~~Please input the letter of the chosen path below.~~~
>""")
            if dalgona_third21_choice == "A" or dalgona_third21_choice == "a": #if user chose path A 
                time.sleep(2)
                print("""
You: 
That seems to be working well actually. It is a lot easier to carve. 
I still have 3 minutes left. 
                    """)
                time.sleep(3)
                print("""
You: 
I am almost there...just a little bit more on this corner...
                    """)
                time.sleep(3)
                #adding another print f for the shape 
                print(f"""
You: 
Did I do it? I think I did!!!

*You remove the {dalgona_first_choice} from the remaining sugar cookie.
 You show it to a gamemaster* 
                    """)
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
Player 259,... """)
                time.sleep(2)
                print("""
Game Master △  ▢  ◯ :
...pass. """)
                glasstiles() #leads to the next game 
            elif dalgona_third21choice== "B" or dalgona_third21_choice == "b": #if user chose to go down path b 
                time.sleep(3)
                print("""
You: 
This may not be the most santitary thing i have done in my life... 
... but its working very well??? I still have 3 minutes left. Perfect.
                """)
                time.sleep(3) #adding suspense 
                print("""
You: 
I am almost there...just a little bit more on this corner...
                    """)
                time.sleep(3)
                #adding a print f for the shape of th user 
                print(f"""
You: 
Did I do it? I think I did!!!

*You remove the {dalgona_first_choice} from the remaining sugar cookie
 Youshow it to a game master* 
                    """)
                time.sleep(4)
                print("""
Game Master △  ▢  ◯ :
Player 259,... """)
                time.sleep(2)
                print("""
Game Master △  ▢  ◯ :
...pass. """)
                glasstiles()   # leading to the next game            
            
            else: # adding an else clause 
                time.sleep(3) 
                print("""
You: 
I did not make any decicion....Back to carving I go...                
                """)
                time.sleep(5)
                print("""
*Crack noise appears*                

You: 
Oh no...""")
                time.sleep(3) #adding a badly ending suspense 
                print("""
Game Master △  ▢  ◯ :
Player 259,...""")
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
... eliminated. """)
                fail() #leading to a failed function 
        elif dalgona_second2_choice == "B" or dalgona_second2_choice == "b": #if user chose path B 
            time.sleep(3)
            print(f"""
You: 
The old man next to me is starting to lick the back of his sugar cookie.
He is also holding it up into the light? 

Should I try that too?             
            """)
            time.sleep(3)
            #adding another input prompt 
            dalgona_third22_choice = input(prompt= """
You:
Yes or no? 

~~~Please input either 'Yes' or 'No' below, to choose your path.~~~            
>""")
            #if clause for yes or no 
            if dalgona_third22_choice == "Yes" or dalgona_third22_choice == "yes" or dalgona_third22_choice== "Y" or dalgona_third22_choice == "y": 
                time.sleep(1)
                print("""
You: 
The old man is onto something. 
This is working quite well actually.""")
                time.sleep(2)
                #adding print f with the shape 
                print(f"""
You: 
I think I almost got the {dalgona_first_choice} out of the sugar cookie...""")
                time.sleep(2)
                print(f"""
*You remove the {dalgona_first_choice} from the remaining sugar cookie.
 You show it to a game master* 
                    """)
                time.sleep(2)
                print("""
Game Master △  ▢  ◯ :
Player 259,... """)
                time.sleep(2)
                print("""
Game Master △  ▢  ◯ :
...pass. """)
                glasstiles() #leading to the next game 
            #else if clause below for the choice no     
            elif dalgona_third22_choice == "No" or dalgona_third22_choice == "no" or dalgona_third22_choice== "N" or dalgona_third22_choice == "n": 
                time.sleep(3)
                print("""
You: 
The old man is gross for doing that. I am surely not doing that.
All I can do is carve. Let me try that.""")
                time.sleep(3)
                print("""
*Crack noise appears*                

You: 
Oh no...""")
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
Player 259,...""")
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
... eliminated. """)
                fail() #unfortunatly choice no leads to fail 
        
        else: #adding an else statement 
            time.sleep(3)
            print("""
You: 
I guess I am on my own then. I will try to carve it out.
I do not have any other option.""")
            time.sleep(3)
            print("""
You: 
This is taking too long. The time is now at 2:34min left. 
What do I do? """)
            time.sleep(2)
            #adding another user input 
            dalgona_third23_choice = input (prompt= """
You:
I think I should try...

A : Licking the sugar cookie. 
    The moisture will help liquify the sugar and makes it easier to carve.
B : Spitting in the tin can and laying down the sugar cookie.

~~~Please input the letter of the chosen path below.~~~
>""")
            if dalgona_third23_choice == "A" or dalgona_third23_choice == "a": #if user chose path A 
                time.sleep(2)
                print("""
You: 
That seems to be working well actually. It is a lot easier to carve. 
I still have 3 minutes left. 
                    """)
                time.sleep(3)
                print("""
You: 
I am almost there...just a little bit more on this corner...
                    """)
                time.sleep(2)
                #adding suspense above and print f below for the shape 
                print(f"""
*You remove the {dalgona_first_choice} from the remaining sugar cookie.
 You show it to a gamemaster* 
                    """)
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
Player 259,... """)
                time.sleep(2)
                print("""
Game Master △  ▢  ◯ :
...pass. """)
                glasstiles() #leading to the next room 
            elif dalgona_third23choice== "B" or dalgona_third23_choice == "b": #if user chose path B 
                time.sleep(2)
                print("""
You: 
This may not be the most santitary thing i have done in my life... 
... but its working very well??? I still have 3 minutes left. Perfect.
                """)
                time.sleep(3)
                print("""
You: 
I am almost there...just a little bit more on this corner...
                    """)
                time.sleep(3)
                #adding suspense above and print f for the shape below 
                print(f"""
You: 
Did I do it? I think I did!!!

*You remove the {dalgona_first_choice} from the remaining sugar cookie.
 You show it to a gamemaster* 
                    """)
                time.sleep(4)
                print("""
Game Master △  ▢  ◯ :
Player 259,... """)
                time.sleep(2)
                print("""
Game Master △  ▢  ◯ :
...pass. """)
                glasstiles() #leads to the next room             
            
            else: #else statement right here 
                time.sleep(3)
                print("""
You: 
I did not make any decicion....Back to carving I go...                
                """)
                time.sleep(5)
                print("""
*Crack noise appears*                

You: 
Oh no...""")
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
Player 259,...""")
                time.sleep(3) #adding a badly ending suspense 
                print("""
Game Master △  ▢  ◯ :
... eliminated. """)
                fail() #leads to the fail function 
            
    else: #adding an else clause 
        print("""
Game Master △  ▢  ◯ :
Player 259, 
You did not decide a shape that is choosable.     
            """)
        time.sleep(4)
        print("""
Player 259... 
""")
        time.sleep(2) #badly ending suspense right here 
        print("""
            
\U0001f4a5            
            
...has been eliminated.            
            """)
        fail() #leads to the fail function 

#####################SETTING UP THE NEXT GAME 
def glasstiles():
    #creating a list for the directions left and right with upper and lower letter 
    glass_lst= ['Left', 'left', 'Right', 'right']
    print("""
Game Master △  ▢  ◯ :
All successful players, 
Please leave the playground immediatly and return to the dorm hall.
    """)
    time.sleep(3)
    print("""
Game Master △  ▢  ◯ :
Here is the outcome of the previous game: 
96 players have been eliminated. 
The price fund now stands at: $USD2,675,000.
There are 12 surviving players.

Please await further instructions on the final game. """)
    time.sleep(3)
    print("""
Game Master △  ▢  ◯ :
All players, 
Please follow the staff to the the game hall..
""")
    time.sleep(3) #adding time for user to read 
    print("""
You: 
This game hall is all white...
There are 12 numbered mannequins standing on a platform, with vests on...
What does this mean?""")
    time.sleep(3)
    print("""
Game Master △  ▢  ◯ :
Welcome, players, to the final physical game. 
Before we begin, choose one of the mannequins that you see presented before you. 
Once you have chosen, take the corresponding vest.
They are numbered 1 through 12.
""")
    time.sleep(5)
    print("""
*You breath deeply*

You: 
There are 12 people left, and there are 12 numbers...""")
    time.sleep(2)
    print("""
Game Master △  ▢  ◯ :
Attention players, 
The number you see on the mannequins correspond to the order in 
Which you will be playing.
Please make your decision carefully.
""")
#creating a random function for user 
    number = random.randint(1,12) # random number remains the same for each guess
    guesses = 2 #user has 2 guesses 


# looping until a user is out of guesses
    while guesses > 0: #while loop beginning here 
        choice = input("""
You: 
Which number should I choose?

~~~Please input the primary number of the mannequin (1-12) of your choosing below.~~~
>""")

    # converting choice for numerical comparison
        choice = int(choice) #making sure that the user input a number aka integer 
      
    # conditional statement based on user input
        if choice == number: #if user input the correct number
            print("""
You: 
Ok I am luckiy, that number was not taken. But does that help? """)
            time.sleep(3)
            #introducing and explaining the next game 
            print("""
Game Master △  ▢  ◯ :
Players, 
Let me welcome you to the thrid and final game. 
The third game is: 
 ██████╗ ██╗      █████╗ ███████╗███████╗                             
██╔════╝ ██║     ██╔══██╗██╔════╝██╔════╝                             
██║  ███╗██║     ███████║███████╗███████╗                             
██║   ██║██║     ██╔══██║╚════██║╚════██║                             
╚██████╔╝███████╗██║  ██║███████║███████║                             
 ╚═════╝ ╚══════╝╚═╝  ╚═╝╚══════╝╚══════╝                             
                                                                      
███████╗████████╗███████╗██████╗ ██████╗ ██╗███╗   ██╗ ██████╗        
██╔════╝╚══██╔══╝██╔════╝██╔══██╗██╔══██╗██║████╗  ██║██╔════╝        
███████╗   ██║   █████╗  ██████╔╝██████╔╝██║██╔██╗ ██║██║  ███╗       
╚════██║   ██║   ██╔══╝  ██╔═══╝ ██╔═══╝ ██║██║╚██╗██║██║   ██║       
███████║   ██║   ███████╗██║     ██║     ██║██║ ╚████║╚██████╔╝       
╚══════╝   ╚═╝   ╚══════╝╚═╝     ╚═╝     ╚═╝╚═╝  ╚═══╝ ╚═════╝        
                                                                      
███████╗████████╗ ██████╗ ███╗   ██╗███████╗███████╗                  
██╔════╝╚══██╔══╝██╔═══██╗████╗  ██║██╔════╝██╔════╝                  
███████╗   ██║   ██║   ██║██╔██╗ ██║█████╗  ███████╗                  
╚════██║   ██║   ██║   ██║██║╚██╗██║██╔══╝  ╚════██║                  
███████║   ██║   ╚██████╔╝██║ ╚████║███████╗███████║                  
╚══════╝   ╚═╝    ╚═════╝ ╚═╝  ╚═══╝╚══════╝╚══════╝                   
The stepping stones before you are made from one of two types of glass: 
One will be tempered glass, the other will be normal glass. 
The tempered glass stepping stones are strong enough to hold the weight of two people. 
However, 
The normal glass will break even if just one person steps on it.
For this game, 
You will guess which of one of the next two tiles is the tile made of the stronger tempered glass, 
And only step on those across the 14 pairs of tiles. 
You may then cross over to the other side safely and pass this game.
            """)
            time. sleep(10) #giving user time to read 
            print("""
Game Master △  ▢  ◯ :
For this game, you will have 12 minutes.
Players must cross the bridge within those 12 minutes.
Each player, take off your shoes, then go up to the tiles in order. 
With that, let the game begin. """)
            
            time.sleep(3)
            print("""
You: 
Some tiles have been cleared so far. """)
            time.sleep(2)
            #setting up input for user 
            glasstiles_second1_choice= input (prompt= """
You: 
Oh no... It is my turn now... 
Which glass tile should I choose? Left or right? 


~~~Please input which glass tile you would like to choose below ('left' or 'right)'.~~~
>""")
            #setting up a for loop 
            for glasstiles_second1_choice in glass_lst: 
                
                print("""
You: 
It did not break!!! I am one step closer.
I will jump on the right one next. """)
                time.sleep(2) 
                    #setting up next input for user 
                 #this one lets both directions win 
                print(""" 
You: 
I MADE IT!!! I CAN NOT BELIEVE IT!!! I SURVIVED ALL THREE GAMES!!!
""")
                finalquestion() #leads to final stage 

        elif choice != number: #if the vest number chosen was not guessed right 
            guesses -= 1 #you loose a chance to guess 

            if guesses > 0: #if you have more than 0 guesses remaining 
                print(f"""
You: 
That number was just chosen by player 045. 
There are {guesses} players remaining to choose another mannequin.
I better choose another number.""") #print f gives how many guesses aka players are left to choose 
                time.sleep(3)
            elif guesses == 0: #if out of guesses 
                print(f"""
You: 
That number was also chosen...
The only number left is... {number}...
""") #if out of guesses, the code chooses a number 
                time.sleep(3)
                print("""
Game Master △  ▢  ◯ :
Hello players, 
Let me welcome you to the thrid and final game. 
The third game is: 
 ██████╗ ██╗      █████╗ ███████╗███████╗                             
██╔════╝ ██║     ██╔══██╗██╔════╝██╔════╝                             
██║  ███╗██║     ███████║███████╗███████╗                             
██║   ██║██║     ██╔══██║╚════██║╚════██║                             
╚██████╔╝███████╗██║  ██║███████║███████║                             
 ╚═════╝ ╚══════╝╚═╝  ╚═╝╚══════╝╚══════╝                             
                                                                      
███████╗████████╗███████╗██████╗ ██████╗ ██╗███╗   ██╗ ██████╗        
██╔════╝╚══██╔══╝██╔════╝██╔══██╗██╔══██╗██║████╗  ██║██╔════╝        
███████╗   ██║   █████╗  ██████╔╝██████╔╝██║██╔██╗ ██║██║  ███╗       
╚════██║   ██║   ██╔══╝  ██╔═══╝ ██╔═══╝ ██║██║╚██╗██║██║   ██║       
███████║   ██║   ███████╗██║     ██║     ██║██║ ╚████║╚██████╔╝       
╚══════╝   ╚═╝   ╚══════╝╚═╝     ╚═╝     ╚═╝╚═╝  ╚═══╝ ╚═════╝        
                                                                      
███████╗████████╗ ██████╗ ███╗   ██╗███████╗███████╗                  
██╔════╝╚══██╔══╝██╔═══██╗████╗  ██║██╔════╝██╔════╝                  
███████╗   ██║   ██║   ██║██╔██╗ ██║█████╗  ███████╗                  
╚════██║   ██║   ██║   ██║██║╚██╗██║██╔══╝  ╚════██║                  
███████║   ██║   ╚██████╔╝██║ ╚████║███████╗███████║                  
╚══════╝   ╚═╝    ╚═════╝ ╚═╝  ╚═══╝╚══════╝╚══════╝                   
The stepping stones before you are made from one of two types of glass: 
One will be tempered glass, the other will be normal glass. 
The tempered glass stepping stones are strong enough to hold the weight of two people. 
However, 
The normal glass will break even if just one person steps on it.
For this game, 
You will guess which of one of the next two tiles is the tile made of the stronger tempered glass, 
And only step on those across the 14 pairs of tiles. 
You may then cross over to the other side safely and pass this game.
            """)
                time. sleep(10)
                print("""
Game Master △  ▢  ◯ :
For this game, you will have 12 minutes.
Players must cross the bridge within those 12 minutes.
Each player, take off your shoes, then go up to the tiles in order. 
With that, let the game begin. """)
                time.sleep(3) #time to read for user 
                print("""
You: 
Some tiles have been cleared so far. """)
                time.sleep(2)
                #setting up new input 
                glasstiles_second1_choice= input (prompt= """
You: 
Oh no... It is my turn now... 
Which glass tile should I choose? Left or right? 


~~~Please input which glass tile you would like to choose below ('left' or 'right)'.~~~
>""")
                for glasstiles_second1_choice in glass_lst: #if choice is in the list 
                    
                    print("""
You: 
It did not break!!! I am one step closer.
I will jump on the right one next. """)
                time.sleep(2) 
 #this one lets both directions win 
                print(""" 
You: 
I MADE IT!!! I CAN NOT BELIEVE IT!!! I SURVIVED ALL THREE GAMES!!!
""")
                finalquestion() 
                         
                         

            else: #else statement for the chosen number 
                print("""
Game Master △  ▢  ◯ :
Player 259, 
You have not chosen a number. 
You are herby eliminated.

\U0001f4a5
""")
                fail() #leads to fail 

    
        else: #else for chosen number 
            print("""
Game Master △  ▢  ◯ :
Player 259, 
You have not chosen a number. 
You are herby eliminated.

\U0001f4a5
""")
            fail() #leads to fail 
###########################THE WIN          
def win():
    time.sleep(2)
    print("""
                                                                     
                                                                     
                                                                     
                                 %%%%%%%%%                           
                              %%%%#------%%%%                        
                             %%#-----%%-----%%%                      
                           %%%----#%%%%%%#---#%%                     
                           %%----%%*-%%-*%*---%%%                    
                          %%%----%%%%%%--------%%                    
                          %%%-------%%%%%%-----%%                    
                           %%----%%--%%-%%*---#%%                    
         %%%%%%%%%%%%%%%%==*%%----%%%%%%%*---=%%                     
      %%%%%+========+=========-------%#-----%%%                      
      %%====================%%%%%%%%%%%-----%===%%       %%%    %%   
      %%%=============================%%%%%======%%%    %%%%%   %%   
        %%%==============================+*========%%% %%% %%%  %%   
          %%========================================%%  %%%%%%%%%    
         %%===========================================    %%%%%      
        %%%====%%%%=================================#%%%%%%          
     %%%%%=====#%%%=====================================             
   %%%=================================================%%            
   %%==================================================%%            
   %%=================================================%%%            
   %%=================================================%%             
   %%#===============================================%%%             
    %%#=============================================#%%              
     %%%%%%%%%=====================================+%%               
             %%%==================================+%%                
               %%%+==============================#%%                 
                %%%=============================%%%                  
                %%==========%%%%%%%%#==========%%%                   
               %%%=========%%%%%% %%==========%%                     
               %%%%%%%%%%%%%%     %%%%%%%%%%%%%                      
                %%%%%%%%%%%%      %%%%%%%%%%%%                       
                                                                     
""")
    time.sleep(3)
    #the following dialogue is from the show, cited below 
    print("""
Game Master △  ▢  ◯ :
Player 259, 
You should celebrate. 
That was quite the game there. 

You: 
Why? How can you 'eliminate' so many people from the face of the earth?

Game Master △  ▢  ◯ :
You bet on horses, it is the same here, but we bet on humans.
You are our horses.
We did not expect you to finish your race to the end. 

You: 
Who are you?

Game Master △  ▢  ◯ :
It was a dream. Just think of it that way.
And it really was not a bad one for you, either. 
Enjoy your money. 
Till we meet again.

*Gas enters the room, you are intoxicated and faint*

You: 
Was it really just a dream?
""")
    exit() # Ends the game
##############SETTING UP LAST STAGE             
def finalquestion():
    time.sleep(3)
    print("""
Game Master △  ▢  ◯ :
Players 259, 291 and 039, we sincerly congratulate and commend you all, 
For successfully making it through the first 3 games.
The 3 of you are now the finalists.  
""")
    time.sleep(3) #give time to read 
    print("""
Game Master △  ▢  ◯ :
Please follow the staff into the final room. """)
    time.sleep(2)
    print("""
*You enter a room, with a table in the middle. 
 The table has the shape of a triangle, on each edge is a chair. 
 In front of each chair, a feast of cooked foods, fruits and wines is layed out.*
""")
    time.sleep(3)
    print("""
Game Master △  ▢  ◯ :
Tonight's feast, is prepared as a token of gratitude for the sacrifice and effort 
That you finalists have made. 
""")
    time.sleep(3)
    #input last user input 
    print("""
Game Master △  ▢  ◯ :
Finalists, 
The final part of the games is a simple question. 
We hope you enjoyed your meal, but with that...

Welcome to the final part.

We will only ask this question to player 259, as they were the first to finish their wine.""") 
    winningplayer_lst=[259]


# looping until a user guesses correctly
    while True:
        choice = input(prompt="""
Game Master △  ▢  ◯ :
The final question is the following: 
Who deserves to win the price fund? 

Player 259?
Player 291?
Or player 039?


~~~Hint: You have made it this far, do you want another player to win or yourself?~~~

~~~Please input the NUMBER of the player you believe deserves to win ('259', '291', or '039').~~~
>""")
    
        try:
        # converting choice for numerical comparison
            choice = int(choice)
            print("""
You: 
I hope that is the right choice...""")
            time.sleep(2)
    
        except:
            input(prompt = """
You: 
Are you sure you want another player to win than yourself?
Here is the question. 
""")
            continue
    
    # conditional statement based on user input
        if choice in winningplayer_lst:
            print("""
\U0001f4a5     \U0001f4a5

Game Master △  ▢  ◯ :
Player 259...""")
            time.sleep(3) #the best possible suspense 
            print("""
...wins. They were the deserving player to win the games.""")
            time.sleep(2)
            win()
            break

        elif choice not in winningplayer_lst:
            print("""
Game Master △  ▢  ◯ : 
Are you sure you want another player to win than yourself? 
Here is the question again. 
""")
            time.sleep(2)
    
    # setting a different error message for inner and outer loops
        else:
            print("\nSomething went wrong.")
    

        
###########################THE WIN  (in here twice for bug preventio)        
def win():
    time.sleep(2)
    print("""
                                                                     
                                                                     
                                                                     
                                 %%%%%%%%%                           
                              %%%%#------%%%%                        
                             %%#-----%%-----%%%                      
                           %%%----#%%%%%%#---#%%                     
                           %%----%%*-%%-*%*---%%%                    
                          %%%----%%%%%%--------%%                    
                          %%%-------%%%%%%-----%%                    
                           %%----%%--%%-%%*---#%%                    
         %%%%%%%%%%%%%%%%==*%%----%%%%%%%*---=%%                     
      %%%%%+========+=========-------%#-----%%%                      
      %%====================%%%%%%%%%%%-----%===%%       %%%    %%   
      %%%=============================%%%%%======%%%    %%%%%   %%   
        %%%==============================+*========%%% %%% %%%  %%   
          %%========================================%%  %%%%%%%%%    
         %%===========================================    %%%%%      
        %%%====%%%%=================================#%%%%%%          
     %%%%%=====#%%%=====================================             
   %%%=================================================%%            
   %%==================================================%%            
   %%=================================================%%%            
   %%=================================================%%             
   %%#===============================================%%%             
    %%#=============================================#%%              
     %%%%%%%%%=====================================+%%               
             %%%==================================+%%                
               %%%+==============================#%%                 
                %%%=============================%%%                  
                %%==========%%%%%%%%#==========%%%                   
               %%%=========%%%%%% %%==========%%                     
               %%%%%%%%%%%%%%     %%%%%%%%%%%%%                      
                %%%%%%%%%%%%      %%%%%%%%%%%%                       
                                                                     
""")
    time.sleep(3)
    #the following dialogue is from the show, cited below 
    print("""
Game Master △  ▢  ◯ :
Player 259, 
You should celebrate. 
That was quite the game there. 

You: 
Why? How can you 'eliminate' so many people from the face of the earth?

Game Master △  ▢  ◯ :
You bet on horses, it is the same here, but we bet on humans.
You are our horses.
We did not expect you to finish your race to the end. 

You: 
Who are you?

Game Master △  ▢  ◯ :
It was a dream. Just think of it that way.
And it really was not a bad one for you, either. 
Enjoy your money. 
Till we meet again.

*Gas enters the room, you are intoxicated and faint*

You: 
Was it really just a dream?
""")
    exit() # Ends the game 

    
########### THE FAILURE 
def fail():
    print("""
Game Master △  ▢  ◯ :
Player, 
A choice of yours has led you to your elimination.""")
    print("""
Thank you for playing Squid Game. 
We hope you had as much fun as us. 
We will spare your physical life, as you are one of the hidden sponsors,
Who decided to join the game as a participant. 
If you wish, you may replay the game and will hopefully win next time.

Let us go back to the beginning. 
Make sure you read the instructions carefully this time.

Please hold while we are resetting the game for you, Player 259. 
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~Resetting the Game~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
""")
    time.sleep(5) #adding time for dramatic purposes to restart the game 
    introduction() #brings user back to the introduction 
introduction() #lets the code start at the introduction
# Out:
# Game Master △  ▢  ◯ :
# Welcome to Squid Games Player 259.
#
# You must survive each game in order to win the experiment.
# If you loose in one game, you are eliminated from all following games and have to restart the game.
#
# Each decision you make, will determine your fate in this game.
# Therefore, be careful.
#
# Good luck Player 259.
#
#
# All players please follow the staff to the game hall.
#
#
# You:
# What is this room? I see this figure in the front, like a girl, but it looks more like...
# Like a doll?
# And all of the staff are in these weird red overralls with masks on...
# The masks show either  △ , ▢ , or ◯ .
#
#
# Game Master △  ▢  ◯ :
# Attention, all players. After you enter the game hall please stand
# Behind the white line drawn on the field and await further instructions.
#
# Please await further instructions.
#
#
#
#
# ██████╗ ███████╗██████╗     ██╗     ██╗ ██████╗ ██╗  ██╗████████╗
# ██╔══██╗██╔════╝██╔══██╗    ██║     ██║██╔════╝ ██║  ██║╚══██╔══╝
# ...

# %% [markdown]
# # References:
#
# Filmy, U. (2021, December 28). Squid game | official English trailer 2 | netflix. YouTube: Official English trailer 2 Netflix. https://www.youtube.com/watch?v=l1NsPNWmzP8
#
# Dialogue retrieved from:
# Dong-hyuk (Producer & Director). 2021. 'Squid Game'. netflix.com
